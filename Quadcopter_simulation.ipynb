# %% [markdown]
# # Quadcopter Simulation
# by group 3
# <br>
# you can find instruction in Readme at https://github.com/Fzil0n/QuadCopter_simulation

# %% [markdown]
# ## 1.Import related package

# %%
from Input_GUI import MotorSpeedSliders
from QuadcopterDynamics import QuadcopterDynamics
from Visualization_v1 import Quadcopter3DVisualization, QuadcopterController
import time
import numpy as np
import math

# %% [markdown]
# ## 2.Assign quadcopter's parameters
# g_val = gravitational acceleration
# <br>
# m_val = mass
# <br>
# l_val = lengh between propeller
# <br>
# K_val = lift constant
# <br>
# A_x_val = air resistant in x-axis
# <br>
# A_y_val = air resistant in y-axis
# <br>
# A_z_val = air resistant in z-axis
# <br>
# b_val = Drag constant
# <br>
# Ixx_val = innertial about x-axis
# <br>
# Iyy_val = innertial about y-axis
# <br>
# Izz_val = innertial about z-axis

# %%
g_val = 9.81 
m_val = 0.468
l_val = 0.225
K_val = 2.980*1e-6
A_x_val = 0.0
A_y_val = 0.0
A_z_val = 0.0
b_val = 1.14*1e-7
Ixx_val = 4.856*1e-3
Iyy_val = 4.856*1e-3
Izz_val = 8.801*1e-3

# %% [markdown]
# ## 3.Main loop
# motion guide
# <br>
# balance
# <br>
# m1=m2=m3=m4
# <br>
# spin about z-axis
# <br>
# m1 +- x,m2 -+ x, m3 +- x,m4 -+ x
# <br>
# spin about y-axis
# <br>
# m1 ,m2 -+ x, m3, m4
# <br>
# spin about x-axis
# <br>
# m1 -+ x,m2 , m3, m4
# <br>

# %%
quadcopter = QuadcopterDynamics(g_val, m_val, l_val, K_val, A_x_val, A_y_val, A_z_val, b_val, Ixx_val, Iyy_val, Izz_val)
dt = 0.01 #100 Hz 
quadcopter.set_dt(dt) 

# initial vaule
omega = [0.0, 0.0, 0.0, 0.0] #motor's speed 

# for manual input
# [m1 m2 m3 m4] referent from MATLAB
# om = 1.075
# spd = om*math.sqrt(1/K_val)
# dspd = 0.05*spd
##spin about z-axis and move +z
# omega = [spd-(0.5*dspd), spd+(0.5*dspd), spd-(0.5*dspd), spd+(0.5*dspd)]
##spin about x-axis
# omega = [spd, spd-dspd, spd, spd]
##balance condition
# omega = [620.6108, 620.6108, 620.6108, 620.6108] 
# print("omega", omega)


deltas = np.zeros(6,)
state = "init_state"
sim_time = 300 # simulation for 5 sec

myTimer = time.time()
print("Start time : ",myTimer)
step = 0
timeStamp = time.time() + dt
while True:
    if(time.time()-timeStamp >= 0):
        print("========trick=======")
        print("State :",state)
        if step >= sim_time:
            print("Start time : ",myTimer)
            print("Stop time : ", time.time())
            quadcopter_visualization.close_wiondow()
            break
        else:
            match state:
                case "init_state":
                    state = "MotorSpeedSlidersConstruct_state"
                    
                case "MotorSpeedSlidersConstruct_state":
                    motor_speed_sliders = MotorSpeedSliders()
                    state = "input_state"
                    
                case "input_state":
                    motor_speed_sliders.run()
                    if(motor_speed_sliders.startSim_press == True):
                        omega = motor_speed_sliders.get_speed()
                        motor_speed_sliders.close_window()
                        state = "VisualizatioConsrtruct_state"
                        del motor_speed_sliders #destructor
                        
                case "VisualizatioConsrtruct_state":
                    quadcopter_visualization = Quadcopter3DVisualization()
                    quadcopter_controller = QuadcopterController(quadcopter_visualization)
                    state = "simulation_state"
                    
                case "simulation_state":
                    # quadcopter 3Dvisualization
                    quadcopter_controller.update_quadcopter_and_plot(deltas=deltas)
                    step = step+1
                    print("Step number : ",step)     
                    quadcopter.calculate_A_matrix(phi_val=quadcopter.orientation[0], theta_val=quadcopter.orientation[1])
                    quadcopter.calculate_B_matrix(omega=omega, orientation=quadcopter.orientation, angularVelocity=quadcopter.angularVelo, linearVelocity=quadcopter.linearVelo)
                    acc = quadcopter.calculate_x_solution()
                    deltas = quadcopter.updateState()        
                    quadcopter.dynamicDebugger()              
        timeStamp = time.time() + dt
# Out:
# Start time :  1702220920.482146
# ========trick=======
# State : init_state
# ========trick=======
# State : MotorSpeedSlidersConstruct_state
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# Entered Speed: 620.0
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 3
# Mouse Position: (459, 226)
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 3
# Mouse Position: (463, 226)
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 3
# Mouse Position: (466, 226)
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 3
# Mouse Position: (468, 226)
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 3
# Mouse Position: (469, 226)
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 3
# Mouse Position: (470, 226)
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 3
# Mouse Position: (472, 226)
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 1
# Mouse Position: (463, 423)
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 1
# Mouse Position: (464, 423)
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 1
# Mouse Position: (465, 423)
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 1
# Mouse Position: (466, 423)
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 1
# Mouse Position: (466, 422)
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 1
# Mouse Position: (467, 422)
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 1
# Mouse Position: (468, 422)
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 1
# Mouse Position: (469, 422)
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 1
# Mouse Position: (470, 421)
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 1
# Mouse Position: (471, 421)
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# Dragging: 1
# Mouse Position: (472, 421)
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# ========trick=======
# State : input_state
# Start Sim status: False
# Start Sim Button Clicked
# Destructor called, MotorSpeedSliders deleted.
# ========trick=======
# State : VisualizatioConsrtruct_state
# Destructor called, Quadcopter3DVisualization deleted.
# ========trick=======
# State : simulation_state
# Step number :  1
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         0.00383447]
# Position :  [0.00000000e+00 0.00000000e+00 5.75169872e-05]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -0.00819282]
# Orientation :  [ 0.          0.         -0.00012289]
# ========trick=======
# State : simulation_state
# Step number :  2
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         0.00766893]
# Position :  [0.         0.         0.00015338]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -0.01638564]
# Orientation :  [ 0.          0.         -0.00032771]
# ========trick=======
# State : simulation_state
# Step number :  3
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.        0.        0.0115034]
# Position :  [0.         0.         0.00028758]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -0.02457846]
# Orientation :  [ 0.          0.         -0.00061446]
# ========trick=======
# State : simulation_state
# Step number :  4
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         0.01533786]
# Position :  [0.         0.         0.00046014]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -0.03277128]
# Orientation :  [ 0.          0.         -0.00098314]
# ========trick=======
# State : simulation_state
# Step number :  5
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         0.01917233]
# Position :  [0.         0.         0.00067103]
# ...
# ========trick=======
# State : simulation_state
# Step number :  261
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.00079558]
# Position :  [0.         0.         1.31604618]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.13832576]
# Orientation :  [ 0.          0.         -2.81189837]
# ========trick=======
# State : simulation_state
# Step number :  262
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.00463004]
# Position :  [0.         0.         1.32611166]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.14651858]
# Orientation :  [ 0.          0.         -2.83340452]
# ========trick=======
# State : simulation_state
# Step number :  263
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.00846451]
# Position :  [0.         0.         1.33621547]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.         0.        -2.1547114]
# Orientation :  [ 0.         0.        -2.8549926]
# ========trick=======
# State : simulation_state
# Step number :  264
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.01229897]
# Position :  [0.         0.         1.34635764]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.16290422]
# Orientation :  [ 0.          0.         -2.87666261]
# ========trick=======
# State : simulation_state
# Step number :  265
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.01613344]
# Position :  [0.         0.         1.35653814]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.17109703]
# Orientation :  [ 0.          0.         -2.89841454]
# ========trick=======
# State : simulation_state
# Step number :  266
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.01996791]
# Position :  [0.         0.         1.36675699]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.17928985]
# Orientation :  [ 0.         0.        -2.9202484]
# ========trick=======
# State : simulation_state
# Step number :  267
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.02380237]
# Position :  [0.         0.         1.37701419]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.18748267]
# Orientation :  [ 0.          0.         -2.94216419]
# ========trick=======
# State : simulation_state
# Step number :  268
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.02763684]
# Position :  [0.         0.         1.38730973]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.19567549]
# Orientation :  [ 0.          0.         -2.96416191]
# ========trick=======
# State : simulation_state
# Step number :  269
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.        0.        1.0314713]
# Position :  [0.         0.         1.39764362]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.20386831]
# Orientation :  [ 0.          0.         -2.98624156]
# ========trick=======
# State : simulation_state
# Step number :  270
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.03530577]
# Position :  [0.         0.         1.40801585]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.21206113]
# Orientation :  [ 0.          0.         -3.00840314]
# ========trick=======
# State : simulation_state
# Step number :  271
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.03914024]
# Position :  [0.         0.         1.41842642]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.22025395]
# Orientation :  [ 0.          0.         -3.03064664]
# ========trick=======
# State : simulation_state
# Step number :  272
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.        0.        1.0429747]
# Position :  [0.         0.         1.42887534]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.22844677]
# Orientation :  [ 0.          0.         -3.05297207]
# ========trick=======
# State : simulation_state
# Step number :  273
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.04680917]
# Position :  [0.        0.        1.4393626]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.23663959]
# Orientation :  [ 0.          0.         -3.07537943]
# ========trick=======
# State : simulation_state
# Step number :  274
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.05064363]
# Position :  [0.         0.         1.44988821]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.24483241]
# Orientation :  [ 0.          0.         -3.09786872]
# ========trick=======
# State : simulation_state
# Step number :  275
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.        0.        1.0544781]
# Position :  [0.         0.         1.46045217]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.25302522]
# Orientation :  [ 0.          0.         -3.12043994]
# ========trick=======
# State : simulation_state
# Step number :  276
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.05831256]
# Position :  [0.         0.         1.47105446]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.26121804]
# Orientation :  [ 0.          0.         -3.14309308]
# ========trick=======
# State : simulation_state
# Step number :  277
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.06214703]
# Position :  [0.         0.         1.48169511]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.26941086]
# Orientation :  [ 0.          0.         -3.16582815]
# ========trick=======
# State : simulation_state
# Step number :  278
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.        0.        1.0659815]
# Position :  [0.         0.         1.49237409]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.27760368]
# Orientation :  [ 0.          0.         -3.18864515]
# ========trick=======
# State : simulation_state
# Step number :  279
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.06981596]
# Position :  [0.         0.         1.50309143]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.         0.        -2.2857965]
# Orientation :  [ 0.          0.         -3.21154408]
# ========trick=======
# State : simulation_state
# Step number :  280
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.07365043]
# Position :  [0.        0.        1.5138471]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.29398932]
# Orientation :  [ 0.          0.         -3.23452494]
# ========trick=======
# State : simulation_state
# Step number :  281
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.07748489]
# Position :  [0.         0.         1.52464112]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.30218214]
# Orientation :  [ 0.          0.         -3.25758773]
# ========trick=======
# State : simulation_state
# Step number :  282
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.08131936]
# Position :  [0.         0.         1.53547349]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.31037496]
# Orientation :  [ 0.          0.         -3.28073244]
# ========trick=======
# State : simulation_state
# Step number :  283
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.08515382]
# Position :  [0.        0.        1.5463442]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.31856778]
# Orientation :  [ 0.          0.         -3.30395908]
# ========trick=======
# State : simulation_state
# Step number :  284
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.08898829]
# Position :  [0.         0.         1.55725326]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.         0.        -2.3267606]
# Orientation :  [ 0.          0.         -3.32726765]
# ========trick=======
# State : simulation_state
# Step number :  285
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.09282276]
# Position :  [0.         0.         1.56820066]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.33495341]
# Orientation :  [ 0.          0.         -3.35065815]
# ========trick=======
# State : simulation_state
# Step number :  286
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.09665722]
# Position :  [0.        0.        1.5791864]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.34314623]
# Orientation :  [ 0.          0.         -3.37413058]
# ========trick=======
# State : simulation_state
# Step number :  287
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.10049169]
# Position :  [0.         0.         1.59021049]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.35133905]
# Orientation :  [ 0.          0.         -3.39768493]
# ========trick=======
# State : simulation_state
# Step number :  288
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.10432615]
# Position :  [0.         0.         1.60127292]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.35953187]
# Orientation :  [ 0.          0.         -3.42132121]
# ========trick=======
# State : simulation_state
# Step number :  289
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.10816062]
# Position :  [0.        0.        1.6123737]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.36772469]
# Orientation :  [ 0.          0.         -3.44503942]
# ========trick=======
# State : simulation_state
# Step number :  290
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.11199509]
# Position :  [0.         0.         1.62351282]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.37591751]
# Orientation :  [ 0.          0.         -3.46883956]
# ========trick=======
# State : simulation_state
# Step number :  291
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.11582955]
# Position :  [0.         0.         1.63469029]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.38411033]
# Orientation :  [ 0.          0.         -3.49272163]
# ========trick=======
# State : simulation_state
# Step number :  292
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.11966402]
# Position :  [0.         0.         1.64590611]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.39230315]
# Orientation :  [ 0.          0.         -3.51668563]
# ========trick=======
# State : simulation_state
# Step number :  293
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.12349848]
# Position :  [0.         0.         1.65716026]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.40049597]
# Orientation :  [ 0.          0.         -3.54073155]
# ========trick=======
# State : simulation_state
# Step number :  294
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.12733295]
# Position :  [0.         0.         1.66845276]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.40868879]
# Orientation :  [ 0.         0.        -3.5648594]
# ========trick=======
# State : simulation_state
# Step number :  295
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.13116741]
# Position :  [0.         0.         1.67978361]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.         0.        -2.4168816]
# Orientation :  [ 0.          0.         -3.58906918]
# ========trick=======
# State : simulation_state
# Step number :  296
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.13500188]
# Position :  [0.        0.        1.6911528]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.42507442]
# Orientation :  [ 0.          0.         -3.61336089]
# ========trick=======
# State : simulation_state
# Step number :  297
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.13883635]
# Position :  [0.         0.         1.70256034]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.43326724]
# Orientation :  [ 0.          0.         -3.63773453]
# ========trick=======
# State : simulation_state
# Step number :  298
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.14267081]
# Position :  [0.         0.         1.71400622]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.44146006]
# Orientation :  [ 0.          0.         -3.66219009]
# ========trick=======
# State : simulation_state
# Step number :  299
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.14650528]
# Position :  [0.         0.         1.72549044]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.          0.         -2.44965288]
# Orientation :  [ 0.          0.         -3.68672758]
# ========trick=======
# State : simulation_state
# Step number :  300
# Linear accelaration :  [[0.         0.         0.38344658]]
# Linear velocity :  [0.         0.         1.15033974]
# Position :  [0.         0.         1.73701301]
# Angular accelaration :  [[ 0.         0.        -0.8192819]]
# Angular velocity :  [ 0.         0.        -2.4578457]
# Orientation :  [ 0.          0.         -3.71134701]
# ========trick=======
# State : simulation_state
# Start time :  1702220920.482146
# Stop time :  1702220939.0155158
